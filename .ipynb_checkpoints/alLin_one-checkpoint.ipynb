# %%
# ----------------------------------------------------------------------------------------
import pickle   
from os import listdir
from os.path import isfile, join
import spacy #load spacy
nlp = spacy.load('en_core_web_sm')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
from collections import defaultdict
import matplotlib.cm as cm
from copy import deepcopy
import math
# import sframe                           
from scipy.sparse import csr_matrix
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import normalize
get_ipython().magic(u'matplotlib inline')



def spacy_cleansing(doc):
    # for token in doc:
    #     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
    #             token.shape_, token.is_alpha, token.is_stop)
    doc = nlp(doc)
    lemmatized = []
    for token in doc:
        con = token.is_bracket or token.is_stop or token.is_quote
        if not con and token.pos_ not in con:
            lemmatized.append(token.lemma_)            
    return lemmatized


def art_to_para(article,threshold=50):
    #     For fragmentation of article text into paragraphs of word-count >= threshold
    #         Parameters :
    #         -------------
    #         article : str
    #         threshold : int, optional, default 50
    para_list = article.split('\n\n')
    if len(para_list) == 1 and len(para_list[0]) > 3.2*threshold :
        temp = para_list[0].split('. ')
        para_list = [". ".join(temp[:math.floor(len(temp)/2)]), ". ".join(temp[math.floor(len(temp)/2):])]
    l = len(para_list)
    def para_thresholding(i=0, clustered_para=[]):
        temp = para_list[i]
        while len(temp.split(" ")) < threshold and i < l - 1:
            temp = temp + " " + para_list[i+1]
            i+=1
        clustered_para.append(temp) 
        if i == l-1:
            cluster_len = len(clustered_para[-1])
            if cluster_len < threshold and cluster_len > 1:
                clustered_para[-2] = clustered_para[-2] + " " + clustered_para[-1]
                del clustered_para[-1]
            return clustered_para
        else:
            return para_thresholding(i+1,clustered_para)
    return para_thresholding()

def load_and_break(keywords, filesave=False):
    mypath = 'news-analyzer/data/'+keywords+'/news/'
    news_text_file = [join(mypath, f) for f in listdir(mypath) if isfile(join(mypath, f))]
    usr_input = input("For whole article, Press a \nFor paragraph segmentation, press p\n")
    bow = [] #........cleaned documents in list of lists
    text = []
    if usr_input == 'a':
        for f in news_text_file:    
            text_article = pickle.load(open(f, 'rb'))
            text.append(text_article['content'])
            temp = spacy_cleansing(text_article['content'])
            bow.append(temp)
    #         print ('article no : ',news_text_file.index(f), sorted(temp),'\n')
    else:
        para_count_in_art = []
        for f in news_text_file:    
            text_article = pickle.load(open(f, 'rb'))
            temp = art_to_para(text_article['content'])
            text += temp
            para_count_in_art.append(len(temp))
            for t in temp:
                temp1 = spacy_cleansing(t)
                bow.append(temp1)
    store_file = {}
    store_file['para_count_in_art'] = para_count_in_art if usr_input != 'a' else 0
    store_file['text'] = text if usr_input != 'a' else 0
    store_file['clean_text_doclist'] = bow
    if filesave:    
        if usr_input == 'a':
            file = 'spacy_cleansing.pkl'
        else:
            file = 'spacy_cleansing_of_paras.pkl'
        pickle.dump(store_file,open(file,'wb'))
    return store_file


# ---------------------------------- tfidf ---------------------------------------------------------------------


def word_count(doc):
    doc_set_all = []
    for docc in doc:
        doc_set = sorted(set().union(docc))
        doc_dict = dict.fromkeys(doc_set, 0)
        for word in docc:
            doc_dict[word] += 1 
        doc_set_all.append(doc_dict.copy())
    return doc_set_all

# print ("wordSet  :   "," ".join(sorted(wordSet)))

def computeTF(doc_set_all,doc):
    tfidf_all = []
    for i in range(len(doc)):
        tfidf = {}
        doc_count = len(doc[i])
        for word, count in doc_set_all[i].items():
            tfidf[word] = round((count+1)/doc_count,4)
    #     print(str(tfDict),'\n'
        tfidf_all.append(tfidf.copy())
    return tfidf_all


def computeIDF(doc_set_all,wordSet):
#     import math
    idfDict = dict.fromkeys(wordSet, 0)
    N = len(doc_set_all)
    for word in wordSet:
        for i in range(N):
        	if word in doc_set_all[i].keys():
        		idfDict[word] += 1
    for word, val in idfDict.items():
        idfDict[word] = math.log10(N / val)
                        
    return idfDict        




def computeTFIDF(tfs, idfs, threshold=0.01):
    tfidfs = []
    new_wordSet = []
    for t in tfs:
        tfidf = {}
        for word, val in t.items():
            ti = round(val*idfs[word],4)
            if ti > threshold:
                tfidf[word] = ti #------rounded for error handeling of data(float64)
                new_wordSet.append(word)
        tfidfs.append(tfidf.copy())
#     print(str(tfidf),'\n')
#     print(str(new_wordset),'\n')
    return tfidfs, new_wordSet


def computeTFIDF_matrix(wordSet, tfidf, l_doc):
    tfidf_wordSet = [dict.fromkeys(wordSet, 0)]*l_doc
    i=0 
    tfidf_matrix = [] 
    for wrdF in tfidf_wordSet:
        tfidf_matrix.append(dict(wrdF, **tfidf[i])) 
        i += 1
    return tfidf_matrix
    
    
def main(stry_kywrds, threshold=0.01, filesave=False):
    processed_doc = load_and_break(stry_kywrds)
    doc = processed_doc['clean_text_doclist']
    wordSet = sorted(set().union(*doc))
    doc_set_all = word_count(doc)
    tfs = computeTF(doc_set_all, doc)
    idfs = computeIDF(doc_set_all, wordSet)
    tfidf, new_wordSet = computeTFIDF(tfs, idfs, threshold)
    wordSet = sorted(set().union(new_wordSet))
    df = pd.DataFrame(computeTFIDF_matrix(wordSet, tfidf, len(doc)))
    if filesave :
        df.to_csv('tfidf_of_paras.csv')
    return df, tfidf, processed_doc['text']


dataframe, tfidf, text = main('sebi rbi conflict', threshold=0.001, filesave=False)
print (dataframe.shape)
# Out:
# For whole article, Press a
# For paragraph segmentation, press p
#  p
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8aa10a715f95> in <module>
#     184
#     185
# --> 186 dataframe, tfidf, text = main('sebi rbi conflict', threshold=0.001, filesave=False)
#     187 print (dataframe.shape)
#
# <ipython-input-5-8aa10a715f95> in main(stry_kywrds, threshold, filesave)
#     170
#     171 def main(stry_kywrds, threshold=0.01, filesave=False):
# --> 172     processed_doc = load_and_break(stry_kywrds)
#     173     doc = processed_doc['clean_text_doclist']
#     174     wordSet = sorted(set().union(*doc))
#
# <ipython-input-5-8aa10a715f95> in load_and_break(keywords, filesave)
#      81         for f in news_text_file:
#      82             text_article = pickle.load(open(f, 'rb'))
# ---> 83             temp = art_to_para(text_article['content'])
#      84             text += temp
#      85             para_count_in_art.append(len(temp))
#
# <ipython-input-5-8aa10a715f95> in art_to_para(article, threshold)
#      62     l = len(para_list)
#      63
# ---> 64     return para_thresholding(para_list)
#      65
#      66 def load_and_break(keywords, filesave=False):
#
# <ipython-input-5-8aa10a715f95> in para_thresholding(para_list, i, clustered_para)
#      36 def para_thresholding(para_list, i=0, clustered_para=[]):
#      37         temp = para_list[i]
# ---> 38         while len(temp.split(" ")) < threshold and i < l - 1:
#      39             temp = temp + " " + para_list[i+1]
#      40             i+=1
#
# NameError: name 'threshold' is not defined

# %%
#------------------------------DIVISIVE CLUSTERING BY BIPARTITION------------------------------
# SOURCE : https://github.com/SSQ/Coursera-UW-Machine-Learning-Clustering-Retrieval/blob/master/Week%206%20PA%201/6_hierarchical_clustering.py
# wiki = sframe.SFrame('people_wiki.gl/')
# dataframe = pd.read_csv('tfidf_of_paras.csv')
X = dataframe.iloc[:,1:].values
X = np.nan_to_num(X)
m, feat = X.shape
tf_idf = X
tf_idf = normalize(tf_idf)
# str(dataframe.iloc[:,0].tolist())


def bipartition(cluster, maxiter=400, num_runs=4, seed=None):
    data_matrix = cluster['matrix']
    dataframe   = cluster['dataframe']
    kmeans_model = KMeans(n_clusters=2, max_iter=maxiter, n_init=num_runs, random_state=seed, n_jobs=1)
    kmeans_model.fit(data_matrix)
    centroids, cluster_assignment = kmeans_model.cluster_centers_, kmeans_model.labels_
    data_matrix_left_child, data_matrix_right_child = data_matrix[cluster_assignment==0], data_matrix[cluster_assignment==1]
#     cluster_assignment_sa = sframe.SArray(cluster_assignment) ##     AG
    cluster_assignment_sa = cluster_assignment                 ##     AG
    dataframe_left_child, dataframe_right_child = dataframe[cluster_assignment_sa==0], dataframe[cluster_assignment_sa==1]
    cluster_left_child  = {'matrix': data_matrix_left_child,
                           'dataframe': dataframe_left_child,
                           'centroid': centroids[0]}
    cluster_right_child = {'matrix': data_matrix_right_child,
                           'dataframe': dataframe_right_child,
                           'centroid': centroids[1]}
    return (cluster_left_child, cluster_right_child)


data = {'matrix': tf_idf, 'dataframe': dataframe} 
cluster_list = [bipartition(data, maxiter=100, num_runs=6, seed=1)]
i = 0
last_layer = []
while i != len(cluster_list):
    if len(cluster_list[i][0]['matrix']) > 80:
        cluster_list.append(bipartition(cluster_list[i][0], maxiter=100, num_runs=6, seed=1))
    else:
        last_layer.append(cluster_list[i][0])
    if len(cluster_list[i][1]['matrix']) > 80:
        cluster_list.append(bipartition(cluster_list[i][1], maxiter=100, num_runs=6, seed=1))
    else:
        last_layer.append(cluster_list[i][1])
    i += 1
print('PARA_COUNT IN LOWEST {}-CLUSTERS: \n{}'.format(len(last_layer),str([len(x['matrix']) for x in last_layer])))
# Out:
# PARA_COUNT IN LOWEST 15-CLUSTERS:
# [18, 39, 32, 68, 56, 46, 62, 44, 44, 68, 66, 45, 54, 80, 36]

# %%
ii = 1
for j in last_layer:
    for i in j['dataframe'].index.tolist():
        print('\033[1m'+'CLUSTER NO : {} with {} articles'.format(ii, len(j['matrix']))+'\033[0m')
        print (i, '\n', text[int(i)], '\n\n',tfidf[int(i)], '\n-----------------------------------------------------------------------------\n')
    ii += 1
    print('\n\n\n\n\n\n\n\n\n\n<<             ---- END OF CLUSTER --------             >>\n\n\n\n\n\n\n\n\n\n\n')
# Out:
# CLUSTER NO : 1 with 18 articles
# 119
#  NCLT and SEBI at Loggerheads over Attachment of Ponzi Debtor's Properties The principal bench of the National Company Law Tribunal (NCLT) has directed market regulator Securities and Exchange Board of India (SEBI) to de-attach the properties of a corporate debtor attached during its execution proceedings. The matter brings into focus the issue of the in-built disagreement between the SEBI Act and the provisions of the Insolvency and Bankruptcy Code (IBC). Especially, how a corporate debtor that was operating as an illegal collective investment scheme (CIS) can be revived under the IBC. Was it due to inactiveness of SEBI to act on  orders of SAT (securities appellate tribunal) to sell assets of the debtor in timely manner?
#
#  {'(': 0.0272, ')': 0.0267, '-': 0.0124, '?': 0.0223, 'Act': 0.0308, 'Attachment': 0.0606, 'Bankruptcy': 0.0535, 'Board': 0.0213, 'CIS': 0.0512, 'Code': 0.0442, 'Company': 0.0415, 'Debtor': 0.0606, 'Exchange': 0.0214, 'IBC': 0.055, 'India': 0.0152, 'Insolvency': 0.0494, 'Law': 0.0442, 'Loggerheads': 0.0606, 'NCLT': 0.0573, 'National': 0.0337, 'Ponzi': 0.0606, 'Properties': 0.0606, 'SAT': 0.0442, 'SEBI': 0.0322, 'Securities': 0.0219, 'Tribunal': 0.0423, 'act': 0.0352, 'appellate': 0.0565, 'asset': 0.0303, 'attach': 0.0612, 'bench': 0.0512, 'bring': 0.0305, 'build': 0.0423, 'collective': 0.0478, 'corporate': 0.0386, 'de': 0.0407, 'debtor': 0.0754, 'direct': 0.0284, 'disagreement': 0.0512, 'especially': 0.0344, 'execution': 0.0494, 'focus': 0.0415, 'illegal': 0.0535, 'inactiveness': 0.0606, 'investment': 0.0262, 'issue': 0.015, 'manner': 0.033, 'market': 0.0157, 'matter': 0.0252, 'operate': 0.0415, 'order': 0.0233, 'principal': 0.0478, 'proceeding': 0.0352, 'property': 0.0388, 'provision': 0.0317, 'regulator': 0.0162, 'revive': 0.0423, 'scheme': 0.0314, 'security': 0.0288, 'sell': 0.0333, 'timely': 0.0494, 'tribunal': 0.0407, '\xa0 ': 0.0344}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 120
#  Last week, in an order, the Bench ruled, "SEBI is directed to de-attach the properties of the corporate debtor and hand over the possession to the resolution professional (RP) to conduct the corporate insolvency resolution process (CIRP) expeditiously, in accordance with the timeline in the Code." A corporate debtor, HBN Dairies and Allies Ltd, an investment scheme operating as an unregistered collective investment scheme (CIS), was admitted into CIRP based on an application filed by some investors.
#
#  {'"': 0.0248, '(': 0.0241, ')': 0.0237, ',': 0.0039, '-': 0.0109, 'Allies': 0.075, 'Bench': 0.075, 'CIRP': 0.0844, 'CIS': 0.068, 'Code': 0.0586, 'Dairies': 0.075, 'HBN': 0.0586, 'Ltd': 0.0493, 'RP': 0.0541, 'SEBI': 0.0171, 'accordance': 0.0574, 'admit': 0.0532, 'application': 0.0433, 'attach': 0.0541, 'base': 0.0399, 'collective': 0.0635, 'conduct': 0.0421, 'corporate': 0.0684, 'de': 0.0541, 'debtor': 0.0751, 'direct': 0.0377, 'expeditiously': 0.075, 'file': 0.0389, 'hand': 0.0532, 'insolvency': 0.068, 'investment': 0.0524, 'investor': 0.0337, 'operate': 0.0551, 'order': 0.031, 'possession': 0.0601, 'process': 0.0383, 'professional': 0.0541, 'property': 0.0515, 'resolution': 0.0773, 'rule': 0.0386, 'scheme': 0.0626, 'timeline': 0.0711, 'unregistered': 0.068, 'week': 0.0447}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 123
#  HBN had told the NCLT that the ongoing recovery proceedings by SEBI would amount to conflict with its plea before the Tribunal admitting it into CIRP. The NCLT noted that SEBI is bound by the directions issued by the SAT, and that provisions of IBC would come into conflict with the stand taken by SEBI.
#
#  {',': 0.0021, '.': 0.0019, 'CIRP': 0.1242, 'HBN': 0.1297, 'IBC': 0.1075, 'NCLT': 0.168, 'SAT': 0.1297, 'SEBI': 0.0755, 'Tribunal': 0.1242, 'admit': 0.1175, 'bind': 0.1364, 'come': 0.0685, 'conflict': 0.0855, 'direction': 0.1061, 'issue': 0.0441, 'note': 0.0905, 'ongoing': 0.1364, 'plea': 0.145, 'proceeding': 0.1035, 'provision': 0.093, 'recovery': 0.1242, 'stand': 0.1156, 'take': 0.0685, 'tell': 0.1022}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 124
#  Admitting HBN's application, the NCLT saw merit in the case made out by the company and observed on the overriding nature of Section 238 of the IBC. It then allowed the RP to take action on the matter. After examining the issue, the RP requested the NCLT to de-attach the company properties in view of Section 14 of IBC, which imposes a moratorium on the corporate debtor's properties.
#
#  {',': 0.0029, '-': 0.0163, '.': 0.0017, '14': 0.0755, '238': 0.0977, 'Admitting': 0.1199, 'HBN': 0.0874, 'IBC': 0.1087, 'NCLT': 0.1134, 'RP': 0.121, 'action': 0.0481, 'allow': 0.0502, 'application': 0.0646, 'attach': 0.0806, 'case': 0.0437, 'company': 0.0512, 'corporate': 0.0509, 'de': 0.0806, 'debtor': 0.0744, 'examine': 0.0706, 'impose': 0.0874, 'issue': 0.0297, 'matter': 0.0499, 'merit': 0.1014, 'moratorium': 0.1117, 'nature': 0.0806, 'observe': 0.0855, 'overriding': 0.1117, 'property': 0.1151, 'request': 0.0724, 'section': 0.1087, 'see': 0.0633, 'view': 0.0666}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 125
#  "In view of the provisions of non-obstante clause of Section 238 of the Code, any right under any other law cannot come in the way of the IBC", NCLT had said in its order. NCLT also observed that in the absence of records and possession of the property belonging to the corporate debtor, the RP would not be able to perform his duties in a time-bound manner and "there would be no possibility of any resolution which is the primary object of the IBC."
#
#  {'"': 0.0552, ',': 0.0026, '-': 0.0219, '.': 0.0012, '238': 0.0876, 'Code': 0.0784, 'IBC': 0.0973, 'NCLT': 0.1015, 'RP': 0.0723, 'able': 0.071, 'absence': 0.0803, 'belong': 0.0803, 'bind': 0.0824, 'clause': 0.095, 'come': 0.0414, 'corporate': 0.0456, 'debtor': 0.0668, 'duty': 0.0699, 'law': 0.0485, 'manner': 0.0585, 'non': 0.0445, 'object': 0.0909, 'observe': 0.0767, 'obstante': 0.1002, 'order': 0.0414, 'perform': 0.0784, 'possession': 0.0803, 'possibility': 0.0803, 'primary': 0.0784, 'property': 0.0688, 'provision': 0.0562, 'record': 0.0688, 'resolution': 0.0688, 'right': 0.0552, 'say': 0.0206, 'section': 0.0649, 'time': 0.0372, 'view': 0.0597, 'way': 0.0547}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 126
#  It also noted that the income-tax (I-T) department had already de-attached the properties belonging to the corporate debtor, and the RP could go ahead with the possession. NCLT's order establishes the IBC's superiority over other laws which, apparently, act as an obstruction during the CIRP.
#
#  {'(': 0.0227, ')': 0.0223, ',': 0.0036, '-': 0.0412, '.': 0.0017, 'CIRP': 0.1059, 'IBC': 0.0916, 'NCLT': 0.0955, 'RP': 0.1019, 'act': 0.0882, 'ahead': 0.1019, 'apparently': 0.1162, 'attach': 0.1019, 'belong': 0.1132, 'corporate': 0.0643, 'de': 0.1019, 'debtor': 0.0941, 'department': 0.0955, 'establish': 0.0882, 'income': 0.0904, 'law': 0.0684, 'note': 0.0771, 'obstruction': 0.1413, 'order': 0.0584, 'possession': 0.1132, 'property': 0.097, 'superiority': 0.1413, 't': 0.1413, 'tax': 0.1019}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 334
#  NCLT and SEBI at Loggerheads over Attachment of Ponzi Debtor's Properties The principal bench of the National Company Law Tribunal (NCLT) has directed market regulator Securities and Exchange Board of India (SEBI) to de-attach the properties of a corporate debtor attached during its execution proceedings. The matter brings into focus the issue of the in-built disagreement between the SEBI Act and the provisions of the Insolvency and Bankruptcy Code (IBC). Especially, how a corporate debtor that was operating as an illegal collective investment scheme (CIS) can be revived under the IBC. Was it due to inactiveness of SEBI to act on  orders of SAT (securities appellate tribunal) to sell assets of the debtor in timely manner?
#
#  {'(': 0.0272, ')': 0.0267, '-': 0.0124, '?': 0.0223, 'Act': 0.0308, 'Attachment': 0.0606, 'Bankruptcy': 0.0535, 'Board': 0.0213, 'CIS': 0.0512, 'Code': 0.0442, 'Company': 0.0415, 'Debtor': 0.0606, 'Exchange': 0.0214, 'IBC': 0.055, 'India': 0.0152, 'Insolvency': 0.0494, 'Law': 0.0442, 'Loggerheads': 0.0606, 'NCLT': 0.0573, 'National': 0.0337, 'Ponzi': 0.0606, 'Properties': 0.0606, 'SAT': 0.0442, 'SEBI': 0.0322, 'Securities': 0.0219, 'Tribunal': 0.0423, 'act': 0.0352, 'appellate': 0.0565, 'asset': 0.0303, 'attach': 0.0612, 'bench': 0.0512, 'bring': 0.0305, 'build': 0.0423, 'collective': 0.0478, 'corporate': 0.0386, 'de': 0.0407, 'debtor': 0.0754, 'direct': 0.0284, 'disagreement': 0.0512, 'especially': 0.0344, 'execution': 0.0494, 'focus': 0.0415, 'illegal': 0.0535, 'inactiveness': 0.0606, 'investment': 0.0262, 'issue': 0.015, 'manner': 0.033, 'market': 0.0157, 'matter': 0.0252, 'operate': 0.0415, 'order': 0.0233, 'principal': 0.0478, 'proceeding': 0.0352, 'property': 0.0388, 'provision': 0.0317, 'regulator': 0.0162, 'revive': 0.0423, 'scheme': 0.0314, 'security': 0.0288, 'sell': 0.0333, 'timely': 0.0494, 'tribunal': 0.0407, '\xa0 ': 0.0344}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 335
#  Last week, in an order, the Bench ruled, "SEBI is directed to de-attach the properties of the corporate debtor and hand over the possession to the resolution professional (RP) to conduct the corporate insolvency resolution process (CIRP) expeditiously, in accordance with the timeline in the Code." A corporate debtor, HBN Dairies and Allies Ltd, an investment scheme operating as an unregistered collective investment scheme (CIS), was admitted into CIRP based on an application filed by some investors.
#
#  {'"': 0.0248, '(': 0.0241, ')': 0.0237, ',': 0.0039, '-': 0.0109, 'Allies': 0.075, 'Bench': 0.075, 'CIRP': 0.0844, 'CIS': 0.068, 'Code': 0.0586, 'Dairies': 0.075, 'HBN': 0.0586, 'Ltd': 0.0493, 'RP': 0.0541, 'SEBI': 0.0171, 'accordance': 0.0574, 'admit': 0.0532, 'application': 0.0433, 'attach': 0.0541, 'base': 0.0399, 'collective': 0.0635, 'conduct': 0.0421, 'corporate': 0.0684, 'de': 0.0541, 'debtor': 0.0751, 'direct': 0.0377, 'expeditiously': 0.075, 'file': 0.0389, 'hand': 0.0532, 'insolvency': 0.068, 'investment': 0.0524, 'investor': 0.0337, 'operate': 0.0551, 'order': 0.031, 'possession': 0.0601, 'process': 0.0383, 'professional': 0.0541, 'property': 0.0515, 'resolution': 0.0773, 'rule': 0.0386, 'scheme': 0.0626, 'timeline': 0.0711, 'unregistered': 0.068, 'week': 0.0447}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 338
#  HBN had told the NCLT that the ongoing recovery proceedings by SEBI would amount to conflict with its plea before the Tribunal admitting it into CIRP. The NCLT noted that SEBI is bound by the directions issued by the SAT, and that provisions of IBC would come into conflict with the stand taken by SEBI.
#
#  {',': 0.0021, '.': 0.0019, 'CIRP': 0.1242, 'HBN': 0.1297, 'IBC': 0.1075, 'NCLT': 0.168, 'SAT': 0.1297, 'SEBI': 0.0755, 'Tribunal': 0.1242, 'admit': 0.1175, 'bind': 0.1364, 'come': 0.0685, 'conflict': 0.0855, 'direction': 0.1061, 'issue': 0.0441, 'note': 0.0905, 'ongoing': 0.1364, 'plea': 0.145, 'proceeding': 0.1035, 'provision': 0.093, 'recovery': 0.1242, 'stand': 0.1156, 'take': 0.0685, 'tell': 0.1022}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 339
#  Admitting HBN's application, the NCLT saw merit in the case made out by the company and observed on the overriding nature of Section 238 of the IBC. It then allowed the RP to take action on the matter. After examining the issue, the RP requested the NCLT to de-attach the company properties in view of Section 14 of IBC, which imposes a moratorium on the corporate debtor's properties.
#
#  {',': 0.0029, '-': 0.0163, '.': 0.0017, '14': 0.0755, '238': 0.0977, 'Admitting': 0.1199, 'HBN': 0.0874, 'IBC': 0.1087, 'NCLT': 0.1134, 'RP': 0.121, 'action': 0.0481, 'allow': 0.0502, 'application': 0.0646, 'attach': 0.0806, 'case': 0.0437, 'company': 0.0512, 'corporate': 0.0509, 'de': 0.0806, 'debtor': 0.0744, 'examine': 0.0706, 'impose': 0.0874, 'issue': 0.0297, 'matter': 0.0499, 'merit': 0.1014, 'moratorium': 0.1117, 'nature': 0.0806, 'observe': 0.0855, 'overriding': 0.1117, 'property': 0.1151, 'request': 0.0724, 'section': 0.1087, 'see': 0.0633, 'view': 0.0666}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 340
#  "In view of the provisions of non-obstante clause of Section 238 of the Code, any right under any other law cannot come in the way of the IBC", NCLT had said in its order. NCLT also observed that in the absence of records and possession of the property belonging to the corporate debtor, the RP would not be able to perform his duties in a time-bound manner and "there would be no possibility of any resolution which is the primary object of the IBC."
#
#  {'"': 0.0552, ',': 0.0026, '-': 0.0219, '.': 0.0012, '238': 0.0876, 'Code': 0.0784, 'IBC': 0.0973, 'NCLT': 0.1015, 'RP': 0.0723, 'able': 0.071, 'absence': 0.0803, 'belong': 0.0803, 'bind': 0.0824, 'clause': 0.095, 'come': 0.0414, 'corporate': 0.0456, 'debtor': 0.0668, 'duty': 0.0699, 'law': 0.0485, 'manner': 0.0585, 'non': 0.0445, 'object': 0.0909, 'observe': 0.0767, 'obstante': 0.1002, 'order': 0.0414, 'perform': 0.0784, 'possession': 0.0803, 'possibility': 0.0803, 'primary': 0.0784, 'property': 0.0688, 'provision': 0.0562, 'record': 0.0688, 'resolution': 0.0688, 'right': 0.0552, 'say': 0.0206, 'section': 0.0649, 'time': 0.0372, 'view': 0.0597, 'way': 0.0547}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 341
#  It also noted that the income-tax (I-T) department had already de-attached the properties belonging to the corporate debtor, and the RP could go ahead with the possession. NCLT's order establishes the IBC's superiority over other laws which, apparently, act as an obstruction during the CIRP.
#
#  {'(': 0.0227, ')': 0.0223, ',': 0.0036, '-': 0.0412, '.': 0.0017, 'CIRP': 0.1059, 'IBC': 0.0916, 'NCLT': 0.0955, 'RP': 0.1019, 'act': 0.0882, 'ahead': 0.1019, 'apparently': 0.1162, 'attach': 0.1019, 'belong': 0.1132, 'corporate': 0.0643, 'de': 0.1019, 'debtor': 0.0941, 'department': 0.0955, 'establish': 0.0882, 'income': 0.0904, 'law': 0.0684, 'note': 0.0771, 'obstruction': 0.1413, 'order': 0.0584, 'possession': 0.1132, 'property': 0.097, 'superiority': 0.1413, 't': 0.1413, 'tax': 0.1019}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 586
#  The Principal Bench of the National Company Law Tribunal (NCLT) has directed market regulator Securities and Exchange Board of India (Sebi) to de-attach the properties of a corporate debtor attached during its execution proceedings. The matter brings into focus the issue of the in-built disagreement between the Sebi Act and the provisions of the Insolvency and Bankruptcy Code (IBC).
#
#  {'(': 0.0335, ')': 0.0329, '-': 0.0229, '.': 0.0012, 'Act': 0.057, 'Bankruptcy': 0.0991, 'Bench': 0.1045, 'Board': 0.0394, 'Code': 0.0818, 'Company': 0.0768, 'Exchange': 0.0396, 'IBC': 0.0677, 'India': 0.0281, 'Insolvency': 0.0914, 'Law': 0.0818, 'NCLT': 0.0707, 'National': 0.0623, 'Principal': 0.1253, 'Sebi': 0.0607, 'Securities': 0.0405, 'Tribunal': 0.0783, 'attach': 0.113, 'bring': 0.0565, 'build': 0.0783, 'corporate': 0.0476, 'de': 0.0754, 'debtor': 0.0696, 'direct': 0.0525, 'disagreement': 0.0949, 'execution': 0.0914, 'focus': 0.0768, 'issue': 0.0278, 'market': 0.0292, 'matter': 0.0467, 'proceeding': 0.0652, 'property': 0.0717, 'provision': 0.0586, 'regulator': 0.03}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 587
#  In an order earlier this week, the tribunal said: "Sebi is directed to de-attach the properties of the corporate debtor and hand over the possession to the Resolution Professional to conduct the Corporate Insolvency Resolution Process (CIRP) expeditiously, in accordance with the timeline in the Code. The tribunal noted that Sebi is bound by the directions issued by the Securities Appellate Tribunal (SAT), and that provisions of IBC would come into conflict with the stand taken by Sebi.
#
#  {'"': 0.0193, '(': 0.021, ')': 0.0206, ',': 0.0022, '-': 0.0128, ':': 0.031, 'Appellate': 0.0794, 'CIRP': 0.0655, 'Code': 0.0684, 'Corporate': 0.0655, 'IBC': 0.0567, 'Insolvency': 0.0765, 'Process': 0.1048, 'Professional': 0.0765, 'Resolution': 0.1241, 'SAT': 0.0684, 'Sebi': 0.0676, 'Securities': 0.0339, 'Tribunal': 0.0655, 'accordance': 0.0669, 'attach': 0.0631, 'bind': 0.0719, 'come': 0.0362, 'conduct': 0.0491, 'conflict': 0.0301, 'corporate': 0.0398, 'de': 0.0631, 'debtor': 0.0583, 'direct': 0.044, 'direction': 0.056, 'earlier': 0.0533, 'expeditiously': 0.0875, 'hand': 0.062, 'issue': 0.0233, 'note': 0.0477, 'order': 0.0362, 'possession': 0.0701, 'property': 0.06, 'provision': 0.0491, 'say': 0.018, 'stand': 0.061, 'take': 0.0362, 'timeline': 0.0829, 'tribunal': 0.0945, 'week': 0.0521}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 589
#  HBN told the tribunal that the ongoing recovery proceedings by Sebi would amount to conflict with its plea before the tribunal admitting it into CIRP. Admitting HBN's application, the tribunal saw merit in the case made out by the company and observed on the overriding nature of Section 238 of the IBC. The tribunal allowed the Resolution Professional (RP) to take action on the matter.
#
#  {'(': 0.0198, ')': 0.0194, ',': 0.0016, '.': 0.0019, '238': 0.1078, 'CIRP': 0.0924, 'HBN': 0.1445, 'IBC': 0.0799, 'Professional': 0.1078, 'RP': 0.0889, 'Resolution': 0.1168, 'Sebi': 0.0477, 'action': 0.0531, 'admit': 0.131, 'allow': 0.0554, 'application': 0.0712, 'case': 0.0482, 'company': 0.0376, 'conflict': 0.0424, 'matter': 0.0551, 'merit': 0.1119, 'nature': 0.0889, 'observe': 0.0943, 'ongoing': 0.1014, 'overriding': 0.1233, 'plea': 0.1078, 'proceeding': 0.0769, 'recovery': 0.0924, 'section': 0.0799, 'see': 0.0698, 'tell': 0.076, 'tribunal': 0.2222}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 590
#  After examining the issue, the RP requested the tribunal to de-attach the company properties in view of Section 14 of IBC, which imposes a moratorium on the corporate debtor's properties. "In view of the provisions of non-obstante clause of Section 238 of the Code, any right under any other law cannot come in the way of the IBC", the tribunal said.
#
#  {'"': 0.037, ',': 0.0036, '-': 0.0245, '.': 0.0013, '14': 0.0755, '238': 0.0977, 'Code': 0.0874, 'IBC': 0.1087, 'RP': 0.0806, 'attach': 0.0806, 'clause': 0.1059, 'come': 0.0462, 'company': 0.0341, 'corporate': 0.0509, 'de': 0.0806, 'debtor': 0.0744, 'examine': 0.0706, 'impose': 0.0874, 'issue': 0.0297, 'law': 0.0541, 'moratorium': 0.1117, 'non': 0.0496, 'obstante': 0.1117, 'property': 0.1151, 'provision': 0.0627, 'request': 0.0724, 'right': 0.0615, 'say': 0.023, 'section': 0.1087, 'tribunal': 0.121, 'view': 0.1, 'way': 0.061}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 591
#  The tribunal also observed that in the absence of records and possession of the property belonging to the corporate debtor, the RP would not be able to perform his duties in a time-bound manner and "there would be no possibility of any resolution which is the primary object of the IBC."
#
#  {'"': 0.0611, ',': 0.0024, '-': 0.027, '.': 0.0014, 'IBC': 0.1198, 'RP': 0.1333, 'able': 0.131, 'absence': 0.1481, 'belong': 0.1481, 'bind': 0.152, 'corporate': 0.0842, 'debtor': 0.1231, 'duty': 0.1288, 'manner': 0.1079, 'object': 0.1677, 'observe': 0.1414, 'perform': 0.1445, 'possession': 0.1481, 'possibility': 0.1481, 'primary': 0.1445, 'property': 0.1268, 'record': 0.1268, 'resolution': 0.1268, 'time': 0.0687, 'tribunal': 0.1333}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 1 with 18 articles
# 592
#  The tribunal noted that the Income Tax Department had already de-attached the properties belonging to the corporate debtor, and the RP could go ahead with the possession. The tribunal's order establishes the IBC's superiority over other laws which apparently act as an obstruction during the CIRP.
#
#  {',': 0.0022, '-': 0.025, '.': 0.002, 'CIRP': 0.1286, 'Department': 0.1342, 'IBC': 0.1112, 'Income': 0.1715, 'RP': 0.1238, 'Tax': 0.1626, 'act': 0.1071, 'ahead': 0.1238, 'apparently': 0.1411, 'attach': 0.1238, 'belong': 0.1375, 'corporate': 0.0781, 'de': 0.1238, 'debtor': 0.1143, 'establish': 0.1071, 'law': 0.0831, 'note': 0.0936, 'obstruction': 0.1715, 'order': 0.0709, 'possession': 0.1375, 'property': 0.1178, 'superiority': 0.1715, 'tribunal': 0.1857}
# -----------------------------------------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
# <<             ---- END OF CLUSTER --------             >>
#
#
#
#
#
#
#
#
#
#
#
# CLUSTER NO : 2 with 39 articles
# 100
#  The investigation into Ajay Shah’s role is similarly superficial. In response to a question in the Lok Sabha conveys that SEBI has started enforcement proceedings against Professor Shah and the NSE for granting ‘special treatment’ to him. The minister’s reply says Mr Shah “had employed a device/ scheme/ artifice, wherein the confidential and sensitive data provided by NSE was misused in fraudulent manner, which resulted in compromising the integrity of the securities market.”
#
#  {'"': 0.0196, ',': 0.0017, '.': 0.0014, 'Ajay': 0.049, 'Lok': 0.1065, 'Mr': 0.0485, 'NSE': 0.0435, 'Professor': 0.0807, 'SEBI': 0.0202, 'Sabha': 0.1065, 'Shah': 0.0923, 'artifice': 0.1065, 'compromise': 0.0666, 'confidential': 0.068, 'convey': 0.0954, 'datum': 0.045, 'device/': 0.1065, 'employ': 0.0889, 'enforcement': 0.0753, 'fraudulent': 0.068, 'grant': 0.0584, 'integrity': 0.068, 'investigation': 0.0419, 'manner': 0.0519, 'market': 0.0248, 'minister': 0.0889, 'misuse': 0.0731, 'proceeding': 0.0555, 'provide': 0.0416, 'question': 0.0469, 'reply': 0.0569, 'response': 0.0555, 'result': 0.0592, 'role': 0.0477, 'say': 0.0183, 'scheme/': 0.1065, 'security': 0.0454, 'sensitive': 0.0843, 'similarly': 0.0807, 'special': 0.0695, 'start': 0.0548, 'superficial': 0.1065, 'treatment': 0.0778, '‘': 0.053, '’': 0.04, '’s': 0.0301, '“': 0.0397}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 101
#  In fact, the issue of privileged access, multiple relationships and the resultant conflict of interest seems like an entire can of worms. Testimony shows that the NSE also gave generous grants to the Indira Gandhi Institute of Development Research (IGIDR). Ajay Shah and his wife Susan Thomas were employees of IGIDR and had ‘full discretion’ on the use of these funds.
#
#  {"'": 0.0475, '(': 0.0179, ')': 0.0176, ',': 0.0022, '.': 0.0017, 'Ajay': 0.0615, 'Development': 0.0895, 'Gandhi': 0.1014, 'IGIDR': 0.142, 'Indira': 0.1059, 'Institute': 0.0837, 'NSE': 0.0364, 'Research': 0.0895, 'Shah': 0.0579, 'Susan': 0.0919, 'Thomas': 0.0681, 'access': 0.0652, 'conflict': 0.0384, 'discretion': 0.1117, 'employee': 0.0715, 'entire': 0.0779, 'fact': 0.0549, 'fund': 0.049, 'generous': 0.1339, 'give': 0.0496, 'grant': 0.0734, 'interest': 0.0344, 'issue': 0.0297, 'like': 0.0519, 'multiple': 0.0744, 'privileged': 0.1014, 'relationship': 0.0755, 'resultant': 0.1117, 'show': 0.0755, 'testimony': 0.0946, 'use': 0.0755, 'wife': 0.0874, 'worm': 0.1339, '‘': 0.0666}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 102
#  IGIDR sub-contracted work to Infotech Financials (one of the two firms offering trading algorithms founded by Sunita Thomas (Susan’s sister), who married to Suprabhat Lala, head of compliance and market operations at the NSE. Ajay Shah and Susan Thomas as leading market academics have been a part of almost all key policy-making committees set up by the finance ministry. Yet, Ms Ramkrishna tells SEBI that she was unaware of any conflict of interest because “she does not recall such a disclosure” being flagged off to her!
#
#  {'!': 0.0617, '"': 0.0174, '(': 0.019, ')': 0.0124, ',': 0.002, '-': 0.0173, 'Ajay': 0.0434, 'IGIDR': 0.0667, 'Infotech': 0.0492, 'Lala': 0.0559, 'Ms': 0.0475, 'NSE': 0.0257, 'Ramkrishna': 0.0559, 'SEBI': 0.0179, 'Shah': 0.0409, 'Sunita': 0.0533, 'Suprabhat': 0.0632, 'Susan': 0.0972, 'Thomas': 0.0721, 'academic': 0.0569, 'algorithm': 0.0632, 'committee': 0.0379, 'compliance': 0.0498, 'conflict': 0.0271, 'contract': 0.0525, 'disclosure': 0.0416, 'finance': 0.0426, 'financial': 0.031, 'firm': 0.0376, 'flag': 0.0632, 'found': 0.0667, 'head': 0.0492, 'interest': 0.0243, 'key': 0.0498, 'lead': 0.0376, 'make': 0.0465, 'market': 0.033, 'marry': 0.0788, 'ministry': 0.0518, 'offer': 0.0492, 'operation': 0.048, 'policy': 0.0366, 'recall': 0.0648, 'set': 0.0419, 'sister': 0.0579, 'sub': 0.0648, 'tell': 0.0486, 'trading': 0.0382, 'unaware': 0.0945, 'work': 0.0412, '’s': 0.0178, '“': 0.0352}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 152
#  Those named so far include: Sanjay Gupta, promoter of OPG Securities Pvt Ltd; his brother-in-law Aman Kokrady; and Ajay Shah, along with unnamed officials from the NSE and SEBI. The sensational new element in the FIR is the allegation that Ajay Shah allegedly used his access to data as an academic to build an algo-trading software that gave OPG Securities an advantage. This is important because several other deep family connections are likely to be exposed as the case progresses. CBI has also alleged that Sanjay Gupta and his brother-in-law, were illegally trading in Dubai, Ghana, Singapore, Hong Kong and China through his firm.
#
#  {',': 0.0027, '-': 0.0263, '.': 0.0012, ':': 0.0213, ';': 0.0449, 'Ajay': 0.0496, 'Aman': 0.0645, 'CBI': 0.0384, 'China': 0.0525, 'Dubai': 0.0601, 'FIR': 0.046, 'Ghana': 0.0645, 'Gupta': 0.0689, 'Hong': 0.0601, 'Kokrady': 0.0645, 'Kong': 0.0601, 'Ltd': 0.0395, 'NSE': 0.0196, 'OPG': 0.065, 'Pvt': 0.047, 'SEBI': 0.0137, 'Sanjay': 0.0901, 'Securities': 0.0349, 'Shah': 0.0467, 'Singapore': 0.0494, 'academic': 0.0433, 'access': 0.0351, 'advantage': 0.0433, 'algo': 0.0362, 'allegation': 0.0297, 'allege': 0.0358, 'allegedly': 0.046, 'brother': 0.0763, 'build': 0.045, 'case': 0.0235, 'connection': 0.0412, 'datum': 0.0304, 'deep': 0.045, 'element': 0.0569, 'expose': 0.0545, 'family': 0.0389, 'far': 0.0375, 'firm': 0.0287, 'give': 0.0267, 'illegally': 0.0645, 'important': 0.0331, 'include': 0.0251, 'law': 0.0436, 'likely': 0.0395, 'name': 0.0419, 'new': 0.0312, 'official': 0.0272, 'progress': 0.0545, 'promoter': 0.026, 'sensational': 0.0569, 'software': 0.0412, 'trade': 0.0347, 'trading': 0.0291, 'unnamed': 0.0569}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 193
#  Those named so far include: Sanjay Gupta, promoter of OPG Securities Pvt Ltd; his brother-in-law Aman Kokrady; and Ajay Shah, along with unnamed officials from the NSE and SEBI. The sensational new element in the FIR is the allegation that Ajay Shah allegedly used his access to data as an academic to build an algo-trading software that gave OPG Securities an advantage. This is important because several other deep family connections are likely to be exposed as the case progresses. CBI has also alleged that Sanjay Gupta and his brother-in-law, were illegally trading in Dubai, Ghana, Singapore, Hong Kong and China through his firm.
#
#  {',': 0.0027, '-': 0.0263, '.': 0.0012, ':': 0.0213, ';': 0.0449, 'Ajay': 0.0496, 'Aman': 0.0645, 'CBI': 0.0384, 'China': 0.0525, 'Dubai': 0.0601, 'FIR': 0.046, 'Ghana': 0.0645, 'Gupta': 0.0689, 'Hong': 0.0601, 'Kokrady': 0.0645, 'Kong': 0.0601, 'Ltd': 0.0395, 'NSE': 0.0196, 'OPG': 0.065, 'Pvt': 0.047, 'SEBI': 0.0137, 'Sanjay': 0.0901, 'Securities': 0.0349, 'Shah': 0.0467, 'Singapore': 0.0494, 'academic': 0.0433, 'access': 0.0351, 'advantage': 0.0433, 'algo': 0.0362, 'allegation': 0.0297, 'allege': 0.0358, 'allegedly': 0.046, 'brother': 0.0763, 'build': 0.045, 'case': 0.0235, 'connection': 0.0412, 'datum': 0.0304, 'deep': 0.045, 'element': 0.0569, 'expose': 0.0545, 'family': 0.0389, 'far': 0.0375, 'firm': 0.0287, 'give': 0.0267, 'illegally': 0.0645, 'important': 0.0331, 'include': 0.0251, 'law': 0.0436, 'likely': 0.0395, 'name': 0.0419, 'new': 0.0312, 'official': 0.0272, 'progress': 0.0545, 'promoter': 0.026, 'sensational': 0.0569, 'software': 0.0412, 'trade': 0.0347, 'trading': 0.0291, 'unnamed': 0.0569}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 468
#  NSE Co-location Scam: SEBI Orders Disgorgement of Profits from NSE and Salaries of former MDs, Ravi Narain and Chitra Ramakrishna In five separate orders, the Securities and Exchange Board of India has slammed the National Stock Exchange (NSE), it’s two controversial, former managing directors Ravi Narain and Chitra Ramakrishna and a host of other entities including Professor Ajay Shah and his sister-in-law Sunita Thomas for what is referred to as the co-location scam.
#
#  {'(': 0.0128, ')': 0.0126, ',': 0.0026, '-': 0.0292, ':': 0.0283, 'Ajay': 0.0441, 'Board': 0.0302, 'Chitra': 0.0825, 'Co': 0.0678, 'Disgorgement': 0.0859, 'Exchange': 0.0456, 'India': 0.0215, 'NSE': 0.0522, 'Narain': 0.075, 'National': 0.0477, 'Orders': 0.0859, 'Professor': 0.0726, 'Profits': 0.0859, 'Ramakrishna': 0.0779, 'Ravi': 0.0789, 'SEBI': 0.0182, 'Salaries': 0.0859, 'Securities': 0.031, 'Shah': 0.0415, 'Stock': 0.0505, 'Sunita': 0.0541, 'Thomas': 0.0488, 'co': 0.0445, 'controversial': 0.0612, 'director': 0.0342, 'entity': 0.0357, 'host': 0.0678, 'include': 0.0335, 'law': 0.0388, 'location': 0.0779, 'manage': 0.0493, 'md': 0.08, 'order': 0.0331, 'refer': 0.0612, 'scam': 0.0759, 'separate': 0.0533, 'sister': 0.0588, 'slam': 0.0859, '’s': 0.018}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 471
#  A long draw investigation that began in 2015 has finally culminated in the orders issued today. In the first order NSE was is directed to take necessary legal actions against Ajay Shah, Infotech Financial Services Pvt. Ltd., Sunita Thomas and Krishna Dagli (Directors of Infotech Financial Services Pvt. Ltd.) for violating the provisions of the "Professional Service Agreement" signed with Infotech and for misusing the data made available to them by NSE. NSE has been asked to submit an action taken report in to SEBI, within three months.
#
#  {'"': 0.0248, '(': 0.012, ')': 0.0118, ',': 0.0019, '.': 0.0018, '2015': 0.0447, 'Agreement': 0.0617, 'Ajay': 0.0413, 'Dagli': 0.0601, 'Directors': 0.068, 'Financial': 0.0651, 'Infotech': 0.0937, 'Krishna': 0.0601, 'Ltd.': 0.1209, 'NSE': 0.0489, 'Professional': 0.0656, 'Pvt': 0.0882, 'SEBI': 0.0171, 'Service': 0.0635, 'Services': 0.0721, 'Shah': 0.0389, 'Sunita': 0.0507, 'Thomas': 0.0457, 'action': 0.0485, 'ask': 0.0335, 'available': 0.0493, 'begin': 0.0515, 'culminate': 0.0805, 'datum': 0.038, 'direct': 0.0377, 'draw': 0.0601, 'finally': 0.0601, 'investigation': 0.0353, 'issue': 0.0199, 'legal': 0.0468, 'long': 0.0447, 'misuse': 0.0617, 'month': 0.0331, 'necessary': 0.0541, 'order': 0.0466, 'provision': 0.0421, 'report': 0.0295, 'sign': 0.0551, 'submit': 0.0452, 'take': 0.031, 'today': 0.0452, 'violate': 0.0586}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 478
#  In two separate orders in the Algo-scandal investigation, the Securities and Exchange Board of India (SEBI) has indicted well-known market economist Ajay Shah and Suprabhat Lala, a senior official of the National Stock Exchange (NSE). The order says a private firm of Sunita Thomas (Mr Lala’s wife and sister-in-law of Ajay Shah), 'commercially exploited' confidential data obtained from the NSE for writing algo trading software.
#
#  {"'": 0.0472, '(': 0.0237, ')': 0.0233, ',': 0.0019, '-': 0.027, 'Ajay': 0.0611, 'Algo': 0.0647, 'Board': 0.0279, 'Exchange': 0.0421, 'India': 0.0199, 'Lala': 0.0787, 'Mr': 0.0404, 'NSE': 0.0362, 'National': 0.0441, 'SEBI': 0.0169, 'Securities': 0.0287, 'Shah': 0.0576, 'Stock': 0.0468, 'Sunita': 0.05, 'Suprabhat': 0.0593, 'Thomas': 0.0451, 'algo': 0.0446, 'commercially': 0.0794, 'confidential': 0.0566, 'datum': 0.0375, 'economist': 0.0672, 'exploit': 0.0627, 'firm': 0.0353, 'indict': 0.0647, 'investigation': 0.0348, 'know': 0.0432, 'law': 0.0358, 'market': 0.0206, 'obtain': 0.0544, 'official': 0.0335, 'order': 0.0459, 'private': 0.0361, 'say': 0.0152, 'scandal': 0.0609, 'senior': 0.0415, 'separate': 0.0493, 'sister': 0.0544, 'software': 0.0508, 'trading': 0.0358, 'wife': 0.0579, 'write': 0.0508, '’s': 0.0167}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 479
#  SEBI has directed NSE to take legal action against Mr Shah, Ms Sunita Thomas, her firm Infotech Financial Services Pvt Ltd, and Krishna Dagli,  director of the company. One of the orders indicts, Ravi Narain and Chitra Ramakrishna, both former managing directors (MD) of NSE overlooking conflict of interest in awarding contract to Infotech Financial. The orders bring out in great detail the close relationship that Dr Shah enjoyed with the NSE group. Dr Shah has worked with the finance ministry and been associated with high level policy committees.
#
#  {'(': 0.0109, ')': 0.0107, ',': 0.003, '.': 0.0013, 'Chitra': 0.0465, 'Dagli': 0.0543, 'Dr': 0.0721, 'Financial': 0.0587, 'Infotech': 0.0634, 'Krishna': 0.0543, 'Ltd': 0.0445, 'MD': 0.0311, 'Mr': 0.037, 'Ms': 0.0408, 'NSE': 0.0441, 'Narain': 0.0423, 'Pvt': 0.053, 'Ramakrishna': 0.0439, 'Ravi': 0.0445, 'SEBI': 0.0154, 'Services': 0.0434, 'Shah': 0.0702, 'Sunita': 0.0458, 'Thomas': 0.0413, 'action': 0.0292, 'associate': 0.0451, 'award': 0.0557, 'bring': 0.0367, 'close': 0.0413, 'committee': 0.0326, 'company': 0.0207, 'conflict': 0.0233, 'contract': 0.0451, 'detail': 0.0465, 'direct': 0.0341, 'director': 0.0435, 'enjoy': 0.0593, 'finance': 0.0367, 'firm': 0.0324, 'great': 0.0451, 'group': 0.0357, 'high': 0.0301, 'indict': 0.0593, 'interest': 0.0209, 'legal': 0.0423, 'level': 0.037, 'manage': 0.0418, 'ministry': 0.0445, 'order': 0.042, 'overlooking': 0.0727, 'policy': 0.0315, 'relationship': 0.0458, 'work': 0.0354, '\xa0 ': 0.0413}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 480
#  “Further, Suprabhat Lala being a senior official of NSE ought to have displayed professional integrity by disclosing to the senior management his connection with Infotech Financials through his wife i.e. Sunita Thomas, which had a strong cause to give rise to a conflict of interest to him as well as to Ajay Shah. Moreover, by sharing internal information and data about NSE and the minutes of technical advisory committee (TAC) with his wife (Sunita Thomas) who was a beneficiary party of the LIX project, Suprabhat Lala has committed breach of his duties to collude with other noticees for the aforesaid fraudulent acts,” the order says.
#
#  {'"': 0.0156, '(': 0.017, ')': 0.0167, ',': 0.0027, 'Ajay': 0.0389, 'Infotech': 0.0441, 'LIX': 0.0581, 'Lala': 0.0751, 'NSE': 0.0345, 'Shah': 0.0366, 'Sunita': 0.0716, 'Suprabhat': 0.0849, 'TAC': 0.054, 'Thomas': 0.0646, 'act': 0.0441, 'advisory': 0.054, 'aforesaid': 0.0758, 'beneficiary': 0.0598, 'breach': 0.0553, 'cause': 0.0342, 'collude': 0.0706, 'commit': 0.0529, 'committee': 0.034, 'conflict': 0.0243, 'connection': 0.0485, 'datum': 0.0358, 'disclose': 0.0553, 'display': 0.067, 'duty': 0.0493, 'financial': 0.0278, 'fraudulent': 0.054, 'i.e.': 0.0758, 'information': 0.0363, 'integrity': 0.054, 'interest': 0.0217, 'internal': 0.0529, 'management': 0.0337, 'minute': 0.0566, 'noticee': 0.0553, 'official': 0.032, 'order': 0.0292, 'ought': 0.0581, 'party': 0.0446, 'professional': 0.051, 'project': 0.051, 'rise': 0.0458, 'say': 0.0145, 'senior': 0.0595, 'share': 0.0328, 'strong': 0.0478, 'technical': 0.054, 'wife': 0.0829, '“': 0.0316}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 481
#  “...the LIX project was itself conceived by Mr Shah to which NSE and its senior officials agreed because of the implicit advantages of having a LIX on the exchange platform. Similarly, it was Mr Shah, who was instrumental in getting the LIX project awarded to Infotech. As far as Mr Shah, Mr Narain and Ms Ramakrishna are concerned, there is no evidence found from the records to suggest that they were aware about the hidden agenda of Mr Shah and his intentions behind the LIX project although all the three noticees are certainly liable for not taking any precaution or checking the antecedents of Infotech, as algo software vendor in the securities market and thereby have not ensured any fairness and transparency nor have they looked at the possible conflict of interest at the time of awarding the contract," the order says.
#
#  {'"': 0.0131, ',': 0.0027, '...': 0.033, 'Infotech': 0.0555, 'LIX': 0.0976, 'Mr': 0.0972, 'Ms': 0.0358, 'NSE': 0.0193, 'Narain': 0.037, 'Ramakrishna': 0.0385, 'Shah': 0.0769, 'advantage': 0.0428, 'agenda': 0.0488, 'agree': 0.0454, 'algo': 0.0358, 'antecedent': 0.0637, 'award': 0.0731, 'aware': 0.039, 'certainly': 0.0445, 'check': 0.0488, 'conceive': 0.0593, 'concern': 0.0354, 'conflict': 0.0204, 'contract': 0.0395, 'ensure': 0.0313, 'evidence': 0.0454, 'exchange': 0.0298, 'fairness': 0.0476, 'far': 0.037, 'find': 0.031, 'get': 0.033, 'have': 0.034, 'hide': 0.0503, 'implicit': 0.0593, 'instrumental': 0.0563, 'intention': 0.0637, 'interest': 0.0183, 'liable': 0.0476, 'lix': 0.0637, 'look': 0.0296, 'market': 0.0166, 'noticee': 0.0464, 'official': 0.0269, 'order': 0.0245, 'platform': 0.0436, 'possible': 0.0395, 'precaution': 0.0593, 'project': 0.0856, 'record': 0.0407, 'say': 0.0122, 'security': 0.0303, 'senior': 0.0333, 'similarly': 0.0539, 'software': 0.0407, 'suggest': 0.0407, 'take': 0.0245, 'time': 0.0221, 'transparency': 0.0395, 'vendor': 0.0593, '“': 0.0265}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 482
#  In fact, the order mentions about an email sent by Mr Shah to Sunita Thomas that revealed how the trading data obtained from NSE was being used for developing algorithm trading product for the securities market. The SEBI order mentions, “Mr Shah held a position of high esteem and influence in the minds of the senior management of NSE, as evident from the statement of Ravi Narain, former MD and CEO of NSE. Mr Shah was capable of influencing the decision making of NSE management, which is exemplified by the fact that he and his wife suggested to NSE and NSE undertook the LIX project for which the Infotech Financials was awarded the contract.”
#
#  {'"': 0.0147, ',': 0.0026, 'CEO': 0.0321, 'Financials': 0.0501, 'Infotech': 0.0417, 'LIX': 0.0549, 'MD': 0.0306, 'Mr': 0.0729, 'NSE': 0.0761, 'Narain': 0.0417, 'Ravi': 0.0439, 'SEBI': 0.0152, 'Shah': 0.0693, 'Sunita': 0.0452, 'Thomas': 0.0407, 'algorithm': 0.0535, 'award': 0.0549, 'capable': 0.0668, 'contract': 0.0445, 'datum': 0.0338, 'decision': 0.0319, 'develop': 0.0458, 'email': 0.0445, 'esteem': 0.0717, 'evident': 0.0606, 'exemplify': 0.0717, 'fact': 0.0492, 'high': 0.0297, 'hold': 0.0271, 'influence': 0.0848, 'making': 0.0566, 'management': 0.0478, 'market': 0.0186, 'mention': 0.0699, 'mind': 0.0549, 'obtain': 0.0491, 'order': 0.0414, 'position': 0.0371, 'product': 0.0445, 'project': 0.0482, 'reveal': 0.0511, 'security': 0.0341, 'send': 0.0433, 'senior': 0.0375, 'statement': 0.0371, 'suggest': 0.0458, 'trading': 0.0485, 'undertake': 0.0535, 'wife': 0.0523, '“': 0.0298}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 483
#  Mr Shah is married to Susan Thomas, the sister of Sunita Thomas, who is director of Infotech Financial. However, in what could have been a criminal conspiracy worthy of celluloid screen, Mr Shah along with some of his immediate family members created a virtual family enterprise and used their connections with NSE officials to gain a computing contract for LIX. Mr Lala, who is married to Sunita Thomas, had at various times headed NSE’s vigilance, compliance, trading and customer relations.
#
#  {',': 0.0049, '.': 0.0013, 'Financial': 0.0487, 'Infotech': 0.0526, 'LIX': 0.0694, 'Lala': 0.0598, 'Mr': 0.0921, 'NSE': 0.0412, 'Shah': 0.0656, 'Sunita': 0.0854, 'Susan': 0.0694, 'Thomas': 0.1028, 'celluloid': 0.0905, 'compliance': 0.0533, 'computing': 0.0905, 'connection': 0.0579, 'conspiracy': 0.0905, 'contract': 0.0562, 'create': 0.0482, 'criminal': 0.0714, 'customer': 0.0676, 'director': 0.0361, 'enterprise': 0.066, 'family': 0.0819, 'gain': 0.0598, 'head': 0.0526, 'immediate': 0.0676, 'married': 0.0843, 'marry': 0.0843, 'member': 0.0465, 'official': 0.0382, 'relation': 0.0714, 'screen': 0.0905, 'sister': 0.062, 'time': 0.0313, 'trading': 0.0408, 'vigilance': 0.0843, 'virtual': 0.0843, 'worthy': 0.0905, '’s': 0.019}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 484
#  “In my view,” Mr Mohanty from SEBI says, “there is no difficulty in sharing of data by Mr Shah with an outside entity for commercial purpose as long as the agreement spells out clearly its objectives and provides for the commercial terms and conditions in the agreement in compliance with the stated data sharing policy of the exchange. However, when a data sharing agreement purely meant for research purposes assumes the colour of a commercial agreement thereby providing privileged access to confidential and exclusive trade data of the exchange to a select few persons who, clandestinely exploit the said data for their commercial gains, it leads to serious issues leading to compromise on market integrity.”
#
#  {'"': 0.0286, ',': 0.0025, 'Mohanty': 0.0567, 'Mr': 0.0531, 'SEBI': 0.0148, 'Shah': 0.0336, 'access': 0.0379, 'agreement': 0.1194, 'assume': 0.0549, 'clandestinely': 0.0649, 'clearly': 0.0452, 'colour': 0.0649, 'commercial': 0.1217, 'compliance': 0.041, 'compromise': 0.0486, 'condition': 0.0395, 'confidential': 0.0496, 'data': 0.0729, 'datum': 0.0658, 'difficulty': 0.0615, 'entity': 0.029, 'exchange': 0.0489, 'exclusive': 0.0508, 'exploit': 0.0549, 'gain': 0.046, 'integrity': 0.0496, 'issue': 0.0173, 'lead': 0.0465, 'long': 0.0387, 'market': 0.0181, 'mean': 0.0383, 'objective': 0.046, 'outside': 0.0549, 'person': 0.0364, 'policy': 0.0301, 'privileged': 0.0589, 'provide': 0.0455, 'purely': 0.0615, 'purpose': 0.0715, 'research': 0.0486, 'say': 0.02, 'select': 0.0477, 'sharing': 0.0995, 'spell': 0.0589, 'state': 0.0342, 'term': 0.0312, 'trade': 0.0375, 'view': 0.0387, '“': 0.029}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 485
#  Mr Shah has been long associated and actively engaged with NSE and several subsidiaries of the Exchange. In fact, Mr Shah and his wife Susan were the only two academicians with deep access into the NSE. They received trading data from the NSE, first, in their personal capacity and, later, as academics associated with Indira Gandhi Institute of Development Research (IGIDR).
#
#  {'(': 0.0179, ')': 0.0176, ',': 0.0043, '.': 0.0017, 'Development': 0.0895, 'Exchange': 0.0424, 'Gandhi': 0.1014, 'IGIDR': 0.0946, 'Indira': 0.1059, 'Institute': 0.0837, 'Mr': 0.0915, 'NSE': 0.0728, 'Research': 0.0895, 'Shah': 0.087, 'Susan': 0.0919, 'academic': 0.0806, 'academician': 0.1199, 'access': 0.0652, 'actively': 0.1014, 'associate': 0.1117, 'capacity': 0.0946, 'datum': 0.0566, 'deep': 0.0837, 'engage': 0.0946, 'fact': 0.0549, 'later': 0.0755, 'long': 0.0666, 'personal': 0.0806, 'receive': 0.0652, 'subsidiary': 0.0806, 'trading': 0.0541, 'wife': 0.0874}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 486
#  In his sworn testimony, Mr Shah had admitted that IGIDR often sub-contracted work to Infotech Financials, recommended its services and also shared data with it. Further, SEBI says, “evidently Mr Lala from the NSE has committed professional compromise by sharing internal data or information with Ms Thomas through the emails referred to at Para-16 of the SCNs and also by accepting invitation from Mr Shah to discuss high-frequency trading (HFT) at NSE at an outside venue in the presence of other Noticees. This leads one to believe that Mr Lala was actively associated with Mr Shah and Ms Thomas and her company, Infotech Financials in their professional activities.”
#
#  {'"': 0.0138, '(': 0.01, ')': 0.0098, ',': 0.0024, '-': 0.0137, 'Financials': 0.0702, 'HFT': 0.0592, 'IGIDR': 0.0529, 'Infotech': 0.0585, 'Lala': 0.0664, 'Mr': 0.1022, 'Ms': 0.0565, 'NSE': 0.0305, 'Noticees': 0.067, 'Para-16': 0.067, 'SEBI': 0.0142, 'Shah': 0.0647, 'Thomas': 0.0571, 'accept': 0.0529, 'actively': 0.0567, 'activity': 0.0416, 'admit': 0.0443, 'associate': 0.0416, 'believe': 0.0422, 'commit': 0.0468, 'company': 0.0191, 'compromise': 0.0468, 'contract': 0.0416, 'datum': 0.0475, 'discuss': 0.0405, 'email': 0.0416, 'evidently': 0.067, 'frequency': 0.0514, 'high': 0.0277, 'information': 0.0321, 'internal': 0.0468, 'invitation': 0.067, 'lead': 0.0298, 'outside': 0.0529, 'presence': 0.0625, 'professional': 0.0676, 'recommend': 0.0416, 'refer': 0.0478, 'say': 0.0128, 'scn': 0.0592, 'service': 0.0381, 'share': 0.0435, 'sub': 0.0514, 'swear': 0.0625, 'testimony': 0.0529, 'trading': 0.0303, 'venue': 0.067, 'work': 0.0327, '“': 0.0279}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 487
#  After examining relevant provisions of the Professional Service Agreement, at para no. 47, signed by Infotech Financials with NSE, the market regulator found that the data received by the company from NSE was confidential and exclusive in nature, which was made available only to the Mr Shah and two directors, Ms Thomas and Krishna Dagli.
#
#  {',': 0.005, '.': 0.0015, '47': 0.13, 'Agreement': 0.1069, 'Dagli': 0.1042, 'Financials': 0.0974, 'Infotech': 0.0811, 'Krishna': 0.1042, 'Mr': 0.071, 'Ms': 0.0784, 'NSE': 0.0635, 'Professional': 0.1137, 'Service': 0.1101, 'Shah': 0.0674, 'Thomas': 0.0792, 'available': 0.0854, 'company': 0.0397, 'confidential': 0.0995, 'datum': 0.0658, 'director': 0.0556, 'examine': 0.0821, 'exclusive': 0.1017, 'find': 0.068, 'market': 0.0363, 'nature': 0.0938, 'para': 0.1395, 'provision': 0.0729, 'receive': 0.0759, 'regulator': 0.0373, 'relevant': 0.0854, 'sign': 0.0955}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 2 with 39 articles
# 488
#  Infotech Financials and its two directors have been in the active business of providing trading solutions to the market participants on algorithmic trade through various products. SEBI says, “The convergence of interests of all the noticees in receiving the data, which was confidential and exclusive in nature, is borne out from the fact that Mr Shah in his own emails has acknowledged its confidential nature and also the fact that he along with other noticees was involved in using the said confidential data for developing algo trading software for sale to traders in the securities market”.
#
# ...
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 602
#  "After deliberation, the Committee believes that the time is right in India to introduce a separation of the roles of the Chairperson and the CEO/MD for listed entities. The Committee observed that such separation, at least at the stage of introduction of the construct, may be more relevant where public shareholders constitute a large portion of the shareholding of a company. In this regard, the Committee considered various thresholds and concluded at least 40% of public shareholding would be an appropriate threshold. Further, in view of the fact that this would require a significant transition from the existing requirements, the Committee believes that listed entities should be given sufficient time to undertake such a transition," the Report from the Kotak Committee, submitted to SEBI says.
#
#  {'"': 0.0212, '%': 0.0292, ',': 0.0037, '.': 0.0012, '40': 0.0434, 'CEO': 0.0308, 'Chairperson': 0.0688, 'Committee': 0.1079, 'India': 0.0173, 'Kotak': 0.0347, 'MD': 0.0294, 'Report': 0.0455, 'SEBI': 0.0146, 'appropriate': 0.0447, 'believe': 0.065, 'company': 0.0196, 'conclude': 0.0502, 'consider': 0.036, 'constitute': 0.0514, 'construct': 0.0688, 'deliberation': 0.0582, 'entity': 0.0429, 'exist': 0.0481, 'fact': 0.0315, 'give': 0.0285, 'introduce': 0.0481, 'introduction': 0.0641, 'large': 0.032, 'list': 0.0469, 'observe': 0.0491, 'portion': 0.0514, 'public': 0.0395, 'regard': 0.0514, 'relevant': 0.0421, 'require': 0.0302, 'requirement': 0.0396, 'right': 0.0353, 'role': 0.0344, 'say': 0.0132, 'separation': 0.0814, 'shareholder': 0.0416, 'shareholding': 0.0681, 'significant': 0.044, 'stage': 0.0641, 'submit': 0.0387, 'sufficient': 0.0769, 'threshold': 0.0961, 'time': 0.0357, 'transition': 0.0872, 'undertake': 0.0514, 'view': 0.0382}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 607
#  Here are other major recommendations of the Committee...
#
#  {'...': 0.6678, 'Committee': 0.6741, 'major': 0.7787, 'recommendation': 0.9191}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 625
#  Ajay Tyagi, Chairman of SEBI, said, "Phase 1 will cover integration at intermediary level. In Phase 2, necessary steps would be taken to enable a single exchange to operate various segments such as equity, equity derivatives, commodity derivatives, currency derivatives, interest rate futures and debt. To permit trading of commodity derivatives and other segments of securities market on single exchange, the Board approved proposal to remove restrictions by making suitable amendments to Securities Contracts (Regulation) (Stock Exchanges and Clearing Corporation) Regulations 2012, which will be effective from 1 October 2018".
#
#  {'"': 0.0196, '(': 0.0143, ')': 0.014, ',': 0.0042, '1': 0.0443, '2': 0.0366, '2012': 0.039, '2018': 0.029, 'Ajay': 0.0327, 'Board': 0.0224, 'Chairman': 0.0454, 'Clearing': 0.0539, 'Corporation': 0.0454, 'Exchanges': 0.0593, 'October': 0.0401, 'Phase': 0.0711, 'Regulations': 0.0476, 'SEBI': 0.0135, 'Securities': 0.023, 'Stock': 0.0375, 'Tyagi': 0.0414, 'amendment': 0.0593, 'approve': 0.0395, 'commodity': 0.0807, 'contract': 0.0395, 'cover': 0.0464, 'currency': 0.0436, 'debt': 0.035, 'derivative': 0.1345, 'effective': 0.0476, 'enable': 0.0563, 'equity': 0.0509, 'exchange': 0.0447, 'future': 0.0428, 'integration': 0.0711, 'interest': 0.0183, 'intermediary': 0.038, 'level': 0.0324, 'make': 0.035, 'market': 0.0166, 'necessary': 0.0428, 'operate': 0.0436, 'permit': 0.0476, 'phase': 0.0488, 'proposal': 0.0464, 'rate': 0.0283, 'regulation': 0.0245, 'remove': 0.0519, 'restriction': 0.0476, 'say': 0.0122, 'security': 0.0303, 'segment': 0.0807, 'single': 0.0653, 'step': 0.0346, 'suitable': 0.0539, 'take': 0.0245, 'trading': 0.0287}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 649
#  Education Viral Acharya has done his Ph.d in Finanace from Stern School of Business, New York University (1996-2001). He had pursued B.Tech in Computer Science and Engineering from IIT Bombay (199-1195). He was awarded with President of India Gold Medalist for highest Grade Point Average (GPA) among 350 students. Editorship
#
#  {'(': 0.0343, ')': 0.0337, ',': 0.0014, '.': 0.0017, '1195': 0.1279, '199': 0.1279, '1996': 0.1145, '2001': 0.1011, '350': 0.1067, 'Acharya': 0.077, 'Average': 0.1279, 'B.Tech': 0.1279, 'Bombay': 0.0835, 'Business': 0.0878, 'Computer': 0.1145, 'Education': 0.0933, 'Engineering': 0.1279, 'Finanace': 0.1279, 'GPA': 0.1279, 'Gold': 0.1279, 'Grade': 0.1279, 'IIT': 0.1011, 'India': 0.0287, 'Medalist': 0.1279, 'New': 0.0878, 'Ph.d': 0.1279, 'Point': 0.1279, 'President': 0.1279, 'School': 0.1067, 'Science': 0.1067, 'Stern': 0.1011, 'University': 0.0968, 'Viral': 0.0784, 'York': 0.1011, 'award': 0.0878, 'editorship': 0.1279, 'high': 0.0474, 'pursue': 0.0933, 'student': 0.1145}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 652
#  Positions Hold He is currently the Member of the Advisory Council of the Reserve Bank of India (RBI) Academy, Academic Council of the National Institute of Securities Markets (NISM), Securities and Exchange Board of India (SEBI) and is the fellow of European Corporate Governance Institute (ECGI). He was Member of the Advisory Board (Review of Finance) and Director of Western Finance Institutions.
#
#  {'(': 0.0445, ')': 0.0437, ',': 0.0018, '.': 0.0011, 'Academic': 0.0993, 'Academy': 0.1109, 'Advisory': 0.1488, 'Bank': 0.0233, 'Board': 0.0523, 'Corporate': 0.0693, 'Council': 0.1386, 'Director': 0.0708, 'ECGI': 0.1109, 'Exchange': 0.0351, 'Finance': 0.0793, 'Governance': 0.1109, 'India': 0.0373, 'Institute': 0.1039, 'Institutions': 0.1109, 'Markets': 0.1109, 'Member': 0.1314, 'NISM': 0.1109, 'National': 0.0552, 'RBI': 0.0232, 'Reserve': 0.0427, 'Review': 0.0877, 'SEBI': 0.0211, 'Securities': 0.0537, 'Western': 0.0993, 'currently': 0.0635, 'european': 0.0993, 'fellow': 0.0993, 'hold': 0.0376, 'position': 0.0514}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 713
#  “This is certainly not a desirable situation as it leads to violation of principles of transparency, equity and fairness in dealing with market participants by the Exchange, which is not permissible under the regulations. Under the circumstances, the acts attributable to the noticees for the reasons recorded and observations made in the foregoing paragraphs of this order, are clearly violative of the various legal provisions, as alleged in the SCNs and the noticees are liable to be held accountable for the acts and the breach of law committed by them,” the order passed by Mr Mohanty says.
#
#  {'"': 0.0294, ',': 0.004, 'Exchange': 0.0337, 'Mohanty': 0.0778, 'Mr': 0.0485, 'accountable': 0.0807, 'act': 0.0834, 'allege': 0.053, 'attributable': 0.0954, 'breach': 0.0695, 'certainly': 0.0666, 'circumstance': 0.0695, 'clearly': 0.062, 'commit': 0.0666, 'deal': 0.0473, 'desirable': 0.0954, 'equity': 0.0509, 'fairness': 0.0712, 'forego': 0.0954, 'hold': 0.0361, 'law': 0.0431, 'lead': 0.0424, 'legal': 0.0555, 'liable': 0.0712, 'market': 0.0248, 'noticee': 0.1045, 'observation': 0.0843, 'order': 0.0552, 'paragraph': 0.0889, 'participant': 0.061, 'pass': 0.0592, 'permissible': 0.0889, 'principle': 0.0889, 'provision': 0.0499, 'reason': 0.0569, 'record': 0.061, 'regulation': 0.0367, 'say': 0.0183, 'scn': 0.0843, 'situation': 0.0601, 'transparency': 0.0592, 'violation': 0.053, 'violative': 0.0954}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 748
#  The Securities and Exchange Board of India (SEBI) has come out with a report on Settlement Mechanisms under securities laws, and is now seeking public comments on the same. A High Level Committee was set up under the Chairmanship of Justice Anil R Dave, former judge of the Supreme Court of India.
#
#  {'(': 0.0234, ')': 0.0229, ',': 0.0028, '.': 0.0017, 'Anil': 0.1745, 'Board': 0.0549, 'Chairmanship': 0.1745, 'Committee': 0.0817, 'Court': 0.0944, 'Dave': 0.1745, 'Exchange': 0.0552, 'High': 0.1167, 'India': 0.0588, 'Justice': 0.1114, 'Level': 0.1563, 'Mechanisms': 0.1745, 'R': 0.1563, 'SEBI': 0.0332, 'Securities': 0.0564, 'Settlement': 0.1322, 'Supreme': 0.1051, 'come': 0.0602, 'comment': 0.107, 'judge': 0.1233, 'law': 0.0705, 'public': 0.0598, 'report': 0.0573, 'security': 0.0743, 'seek': 0.0716, 'set': 0.0774}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 749
#  The committee comprised advocate Pratap Venugopal (Member) and the core team of SEBI consisting of Ananta Barua (Whole Time Member), Babitha Rayadu (Chief General Manager), G Vijayakrishnan (General Manager), L Kajio Mao (Assistant General Manager) and Chaudhary Suraj (Manager). Settlement for securities laws violations was introduced in India in 2007. In order to factor in various issues and elements in its enforcement mechanism, SEBI created a system in 2012 to pursue a quantifiable settlement mechanism that took the form of the SEBI (Settlement of Administrative and Civil Proceedings) Regulations, 2014.
#
#  {'(': 0.0367, ')': 0.036, ',': 0.0022, '2007': 0.047, '2012': 0.0376, '2014': 0.042, 'Administrative': 0.0614, 'Ananta': 0.0685, 'Assistant': 0.0685, 'Babitha': 0.0685, 'Barua': 0.0685, 'Chaudhary': 0.0685, 'Chief': 0.0447, 'Civil': 0.0614, 'G': 0.0542, 'General': 0.0968, 'India': 0.0154, 'Kajio': 0.0685, 'L': 0.0685, 'Manager': 0.1534, 'Mao': 0.0685, 'Member': 0.0813, 'Pratap': 0.0685, 'Proceedings': 0.0685, 'Rayadu': 0.0685, 'Regulations': 0.0458, 'SEBI': 0.026, 'Suraj': 0.0685, 'Time': 0.0542, 'Venugopal': 0.0393, 'Vijayakrishnan': 0.0685, 'advocate': 0.0685, 'committee': 0.0275, 'comprise': 0.047, 'consist': 0.0542, 'core': 0.0519, 'create': 0.0327, 'element': 0.0542, 'enforcement': 0.0484, 'factor': 0.0447, 'form': 0.0438, 'introduce': 0.0429, 'issue': 0.0152, 'law': 0.0277, 'mechanism': 0.063, 'order': 0.0236, 'pursue': 0.05, 'quantifiable': 0.0685, 'security': 0.0292, 'settlement': 0.0773, 'system': 0.0269, 'take': 0.0236, 'team': 0.042, 'violation': 0.0341}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 751
#  1. Amendment to definition of ‘securities laws’ under Settlement Regulations to include other laws by which the SEBI can administer civil and administrative proceedings. Currently, it only includes proceedings initiated under the SEBI Act, the SCRA, the Depositories Act, and the rules and regulations made thereunder. This way, powers given to SEBI under the Companies Act will also be recognised.
#
#  {"'": 0.0465, ',': 0.0042, '.': 0.0021, '1': 0.0545, 'Act': 0.1192, 'Companies': 0.0876, 'Depositories': 0.131, 'Regulations': 0.0876, 'SCRA': 0.131, 'SEBI': 0.0497, 'Settlement': 0.0992, 'administer': 0.1173, 'administrative': 0.131, 'amendment': 0.1093, 'civil': 0.0899, 'currently': 0.075, 'definition': 0.1093, 'give': 0.0485, 'include': 0.0685, 'initiate': 0.0728, 'law': 0.0794, 'power': 0.0591, 'proceeding': 0.1023, 'recognise': 0.0926, 'regulation': 0.0452, 'rule': 0.0562, 'security': 0.0558, 'thereund': 0.131, 'way': 0.0597, '’': 0.0492}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 752
#  2. Recommending a more arduous approach, the Committee has proposed that no application for settlement should be entertained after hearing commences or after 120 days have passed since its filing with the Board. Further, it has been recommended that 25% of the settlement amount per annum be increased for filing after 60 days (of service of notice), as opposed to the current 5%.
#
#  {'  ': 0.0478, '%': 0.0821, '(': 0.0193, ')': 0.0189, ',': 0.0031, '.': 0.0019, '120': 0.1289, '2': 0.0741, '25': 0.0812, '5': 0.08, '60': 0.144, 'Board': 0.0453, 'Committee': 0.0674, 'annum': 0.1201, 'application': 0.0694, 'approach': 0.0883, 'arduous': 0.144, 'commence': 0.1289, 'current': 0.065, 'day': 0.092, 'entertain': 0.1289, 'filing': 0.1184, 'hear': 0.109, 'increase': 0.0662, 'notice': 0.0566, 'oppose': 0.144, 'pass': 0.08, 'propose': 0.0838, 'recommend': 0.1201, 'service': 0.0732, 'settlement': 0.1218}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 755
#  6. The Committee has also recommended that despite pendency of settlement application, there may be cases where it is necessary to initiate proceedings to issue interim directions to protect interest of investors and maintain market integrity. It has, to that extent, recommended that the Settlement Regulations be amended to do away with the stay of such other proceedings.
#
#  {',': 0.0036, '.': 0.0022, '6': 0.1132, 'Committee': 0.0793, 'Regulations': 0.1132, 'Settlement': 0.1282, 'amend': 0.1132, 'application': 0.0816, 'away': 0.1081, 'case': 0.0553, 'despite': 0.0985, 'direction': 0.0904, 'extent': 0.1132, 'initiate': 0.0941, 'integrity': 0.1081, 'interest': 0.0435, 'interim': 0.1162, 'investor': 0.0635, 'issue': 0.0376, 'maintain': 0.0882, 'market': 0.0394, 'necessary': 0.1019, 'pendency': 0.1693, 'proceeding': 0.1323, 'protect': 0.1105, 'recommend': 0.1412, 'settlement': 0.0955, 'stay': 0.1196}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 756
#  7. Apart from structural changes to the High Powered Advisory Committee (HPAC), the Committee has recommended insertion of provisions which allow recusal by members of HPAC (due to conflict of interest) and the resultant manner for taking decisions. 8. The Committee has recommended that a Notice of Settlement (not summary settlement) for defaults other than the ones already covered, be included. The Committee recommends that the applicant will have to make the application for settlement within 15 days from the date of receipt of the settlement notice.
#
#  {'(': 0.0266, ')': 0.0261, ',': 0.0016, '.': 0.0019, '15': 0.0569, '7': 0.0569, '8': 0.0702, 'Advisory': 0.089, 'Committee': 0.1162, 'HPAC': 0.1333, 'High': 0.0664, 'Notice': 0.089, 'Powered': 0.0993, 'Settlement': 0.0752, 'allow': 0.0373, 'apart': 0.0664, 'applicant': 0.0752, 'application': 0.0479, 'change': 0.0437, 'conflict': 0.0285, 'cover': 0.0648, 'date': 0.0524, 'day': 0.0423, 'decision': 0.0396, 'default': 0.0552, 'include': 0.0347, 'insertion': 0.089, 'interest': 0.0255, 'manner': 0.0484, 'member': 0.0457, 'notice': 0.039, 'one': 0.0725, 'provision': 0.0465, 'receipt': 0.0682, 'recommend': 0.1105, 'recusal': 0.0829, 'resultant': 0.0829, 'settlement': 0.1121, 'structural': 0.0829, 'summary': 0.0993, 'take': 0.0343}
# -----------------------------------------------------------------------------
#
# CLUSTER NO : 15 with 36 articles
# 757
#  9. Adopting learnings from the US Securities Exchange Commission and the Competition Commission of India, the Committee has recommended insertion of confidentiality provisions for settlement proceedings.
#
#  {',': 0.0033, '.': 0.003, '9': 0.1896, 'Commission': 0.2903, 'Committee': 0.142, 'Competition': 0.2296, 'Exchange': 0.0959, 'India': 0.0681, 'Securities': 0.098, 'adopt': 0.2398, 'confidentiality': 0.2715, 'insertion': 0.2715, 'learning': 0.2715, 'proceeding': 0.1579, 'provision': 0.142, 'recommend': 0.1686, 'settlement': 0.171}
# -----------------------------------------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
# <<             ---- END OF CLUSTER --------             >>
